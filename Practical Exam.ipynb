# %%
#1

# %%
import pandas as pd

# %%
df1 = pd.read_excel("Dress Sales (1).xlsx")
df1
# Out:
#        Dress_ID  29/8/2013  31/8/2013  2013-02-09 00:00:00  \
# 0    1006032852       2114       2274                 2491
# 1    1212192089        151        275                  570
# 2    1190380701          6          7                    7
# 3     966005983       1005       1128                 1326
# 4     876339541        996       1175                 1304
# ..          ...        ...        ...                  ...
# 495   713391965          0          0                    0
# 496   722565148          0          0                    0
# 497   532874347          0          0                    0
# 498   655464934          0          0                    0
# 499   919930954          0          0                    0
#
#      2013-04-09 00:00:00  2013-06-09 00:00:00  2013-08-09 00:00:00  \
# 0                   2660                 2727                 2887
# 1                    750                  813                 1066
# ...

# %%
df1.head()
# Out:
#      Dress_ID  29/8/2013  31/8/2013  2013-02-09 00:00:00  2013-04-09 00:00:00  \
# 0  1006032852       2114       2274                 2491                 2660
# 1  1212192089        151        275                  570                  750
# 2  1190380701          6          7                    7                    7
# 3   966005983       1005       1128                 1326                 1455
# 4   876339541        996       1175                 1304                 1396
#
#    2013-06-09 00:00:00  2013-08-09 00:00:00  2013-10-09 00:00:00  \
# 0                 2727                 2887                 2930
# 1                  813                 1066                 1164
# 2                    8                    8                    9
# 3                 1507                 1621                 1637
# 4                 1432                 1559                 1570
#
#   2013-12-09 00:00:00 14/9/2013  ... 24/9/2013 26/9/2013 28/9/2013 30/9/2013  \
# ...

# %%
df1.tail()
# Out:
#       Dress_ID  29/8/2013  31/8/2013  2013-02-09 00:00:00  \
# 495  713391965          0          0                    0
# 496  722565148          0          0                    0
# 497  532874347          0          0                    0
# 498  655464934          0          0                    0
# 499  919930954          0          0                    0
#
#      2013-04-09 00:00:00  2013-06-09 00:00:00  2013-08-09 00:00:00  \
# 495                  560                  554                  544
# 496                  875                  866                  861
# 497                  734                  728                  726
# 498                  254                  259                  261
# 499                  538                  545                  558
#
#      2013-10-09 00:00:00 2013-12-09 00:00:00 14/9/2013  ... 24/9/2013  \
# 495                  537                 525       519  ...       400
# ...

# %%
df1[['Dress_ID']]
# Out:
#        Dress_ID
# 0    1006032852
# 1    1212192089
# 2    1190380701
# 3     966005983
# 4     876339541
# ..          ...
# 495   713391965
# 496   722565148
# 497   532874347
# 498   655464934
# 499   919930954
#
# [500 rows x 1 columns]

# %%
df1.dtypes
# Out:
# Dress_ID                 int64
# 29/8/2013                int64
# 31/8/2013                int64
# 2013-02-09 00:00:00      int64
# 2013-04-09 00:00:00      int64
# 2013-06-09 00:00:00      int64
# 2013-08-09 00:00:00      int64
# 2013-10-09 00:00:00      int64
# 2013-12-09 00:00:00     object
# 14/9/2013               object
# 16/9/2013               object
# 18/9/2013               object
# 20/9/2013               object
# 22/9/2013               object
# 24/9/2013                int64
# 26/9/2013              float64
# 28/9/2013                int64
# 30/9/2013              float64
# 2013-02-10 00:00:00    float64
# 2013-04-10 00:00:00    float64
# 2013-06-10 00:00:00      int64
# 2010-08-10 00:00:00    float64
# 2013-10-10 00:00:00    float64
# 2013-12-10 00:00:00      int64
# dtype: object

# %%
df1['Dress_ID'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Name: Dress_ID, Length: 500, dtype: bool

# %%
df1.iloc[0:6,0:7]
# Out:
#      Dress_ID  29/8/2013  31/8/2013  2013-02-09 00:00:00  2013-04-09 00:00:00  \
# 0  1006032852       2114       2274                 2491                 2660
# 1  1212192089        151        275                  570                  750
# 2  1190380701          6          7                    7                    7
# 3   966005983       1005       1128                 1326                 1455
# 4   876339541        996       1175                 1304                 1396
# 5  1068332458          4          5                   11                   13
#
#    2013-06-09 00:00:00  2013-08-09 00:00:00
# 0                 2727                 2887
# 1                  813                 1066
# 2                    8                    8
# 3                 1507                 1621
# 4                 1432                 1559
# 5                   13                   13

# %%
df1.loc[0:3, ['Dress_ID', '31/8/2013','29/8/2013']]
# Out:
#      Dress_ID  31/8/2013  29/8/2013
# 0  1006032852       2274       2114
# 1  1212192089        275        151
# 2  1190380701          7          6
# 3   966005983       1128       1005

# %%
df=pd.read_excel("Attribute DataSet.xlsx")
df
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %%
df.dropna(axis = 1)
# Out:
#        Dress_ID    Style  Rating  Size  Recommendation
# 0    1006032852     Sexy     4.6     M               1
# 1    1212192089   Casual     0.0     L               0
# 2    1190380701  vintage     0.0     L               0
# 3     966005983    Brief     4.6     L               1
# 4     876339541     cute     4.5     M               0
# ..          ...      ...     ...   ...             ...
# 495   713391965   Casual     4.7     M               1
# 496   722565148     Sexy     4.3  free               0
# 497   532874347   Casual     4.7     M               1
# 498   655464934   Casual     4.6     L               1
# 499   919930954   Casual     4.4  free               0
#
# [500 rows x 5 columns]

# %%
df.dropna(thresh=1)
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %%
df
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %%
df.fillna(value=5)
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire              5     chiffon     ruffles
# ...

# %%
df.groupby('Style')

# %%
df.groupby('Style').groups
# Out:
# {'Brief': [3, 18, 22, 33, 37, 40, 41, 89, 167, 169, 177, 365, 366, 391, 400, 431, 445, 494], 'Casual': [1, 6, 14, 15, 21, 27, 30, 31, 32, 35, 39, 42, 43, 47, 48, 49, 51, 52, 53, 56, 61, 62, 63, 65, 66, 67, 69, 73, 74, 75, 76, 77, 78, 80, 84, 85, 86, 90, 91, 94, 95, 96, 97, 101, 102, 107, 108, 109, 111, 112, 116, 117, 118, 125, 129, 130, 136, 138, 143, 144, 146, 147, 150, 154, 156, 158, 160, 162, 165, 168, 170, 171, 173, 175, 180, 182, 183, 186, 189, 194, 195, 197, 200, 201, 202, 205, 207, 210, 211, 212, 214, 215, 217, 218, 219, 220, 221, 222, 223, 224, ...], 'Flare': [8, 11], 'Novelty': [7, 55, 137, 312, 322, 330, 449, 459], 'OL': [92], 'Sexy': [0, 19, 20, 23, 24, 25, 26, 45, 46, 50, 64, 72, 82, 87, 88, 93, 99, 110, 122, 123, 127, 131, 140, 142, 152, 155, 159, 172, 178, 181, 184, 188, 198, 199, 203, 225, 229, 241, 303, 309, 316, 321, 332, 333, 343, 347, 355, 357, 360, 367, 371, 374, 385, 405, 428, 429, 430, 437, 440, 441, 443, 444, 446, 456, 470, 475, 477, 487, 496], 'bohemian': [5, 
# ...

# %%
df.groupby('Size').groups
# Out:
# {'L': [1, 2, 3, 16, 20, 27, 30, 32, 33, 41, 46, 49, 52, 57, 68, 75, 85, 90, 91, 99, 101, 104, 105, 109, 110, 113, 115, 116, 117, 119, 120, 124, 133, 134, 137, 142, 144, 147, 149, 153, 160, 163, 165, 172, 175, 176, 185, 198, 204, 206, 208, 215, 218, 238, 246, 254, 263, 267, 269, 270, 274, 280, 290, 307, 308, 319, 324, 331, 343, 346, 349, 350, 363, 368, 381, 384, 385, 395, 397, 398, 407, 411, 414, 421, 435, 447, 452, 453, 457, 462, 467, 469, 481, 489, 491, 498], 'M': [0, 4, 5, 12, 13, 14, 18, 19, 21, 25, 26, 29, 31, 34, 37, 38, 39, 42, 44, 45, 47, 48, 54, 58, 59, 60, 62, 63, 65, 69, 71, 72, 80, 81, 83, 88, 89, 92, 93, 95, 96, 106, 112, 114, 125, 126, 130, 131, 132, 135, 138, 143, 150, 166, 173, 177, 181, 183, 192, 193, 194, 201, 203, 205, 207, 211, 213, 216, 219, 227, 229, 231, 233, 235, 236, 239, 240, 241, 242, 243, 244, 245, 248, 249, 252, 253, 255, 256, 257, 258, 259, 260, 261, 264, 265, 266, 268, 272, 276, 277, ...], 'S': [23, 55, 56, 64, 67, 74, 86, 87, 94, 98, 151, 155, 161, 168,
# ...

# %%
#2

# %%
data = {'name' : ['Sudh', 'Krish','Nitesh','Tulesco'], 
       'salary': [100, 200, 300, 400],
       'email': ['spatil@mes.ac.in', 'krish@mes.ac.in', 'nitesh@mes.ac.in','tilesco@mes.ac.in'],
        'mobile': [1324123,2314123,341,23423],
       'addr': ['wer', 'ert', 'ert', 'weew']}

# %%
df = pd.DataFrame(data)
df
# Out:
#       name  salary              email   mobile  addr
# 0     Sudh     100   spatil@mes.ac.in  1324123   wer
# 1    Krish     200    krish@mes.ac.in  2314123   ert
# 2   Nitesh     300   nitesh@mes.ac.in      341   ert
# 3  Tulesco     400  tilesco@mes.ac.in    23423  weew

# %%
data1 = {'pf_num':[12,23,34,54],
        'incometax': [132,435,452,123],
         'mobile': [1324123,2314123,341,23423],
         'courses':['ds','big data', 'dl','python']}
df1 = pd.DataFrame(data1)
df1
# Out:
#    pf_num  incometax   mobile   courses
# 0      12        132  1324123        ds
# 1      23        435  2314123  big data
# 2      34        452      341        dl
# 3      54        123    23423    python

# %%
pd.concat([df,df1])
# Out:
#       name  salary              email   mobile  addr  pf_num  incometax  \
# 0     Sudh   100.0   spatil@mes.ac.in  1324123   wer     NaN        NaN
# 1    Krish   200.0    krish@mes.ac.in  2314123   ert     NaN        NaN
# 2   Nitesh   300.0   nitesh@mes.ac.in      341   ert     NaN        NaN
# 3  Tulesco   400.0  tilesco@mes.ac.in    23423  weew     NaN        NaN
# 0      NaN     NaN                NaN  1324123   NaN    12.0      132.0
# 1      NaN     NaN                NaN  2314123   NaN    23.0      435.0
# 2      NaN     NaN                NaN      341   NaN    34.0      452.0
# 3      NaN     NaN                NaN    23423   NaN    54.0      123.0
#
#     courses
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 0        ds
# 1  big data
# 2        dl
# 3    python

# %%
pd.concat([df,df1], axis=1)
# Out:
#       name  salary              email   mobile  addr  pf_num  incometax  \
# 0     Sudh     100   spatil@mes.ac.in  1324123   wer      12        132
# 1    Krish     200    krish@mes.ac.in  2314123   ert      23        435
# 2   Nitesh     300   nitesh@mes.ac.in      341   ert      34        452
# 3  Tulesco     400  tilesco@mes.ac.in    23423  weew      54        123
#
#     mobile   courses
# 0  1324123        ds
# 1  2314123  big data
# 2      341        dl
# 3    23423    python

# %%
pd.merge(df,df1)
# Out:
#       name  salary              email   mobile  addr  pf_num  incometax  \
# 0     Sudh     100   spatil@mes.ac.in  1324123   wer      12        132
# 1    Krish     200    krish@mes.ac.in  2314123   ert      23        435
# 2   Nitesh     300   nitesh@mes.ac.in      341   ert      34        452
# 3  Tulesco     400  tilesco@mes.ac.in    23423  weew      54        123
#
#     courses
# 0        ds
# 1  big data
# 2        dl
# 3    python

# %%
#3

# %%
data9 = {'emp_id':[101,102,103,104],
       'salary':[12,45,53,45],
        'providentfund':[12312,3432,234,535]}
data10 = {'emp_id': [101,102,104,103],
       'mobile_no':[12321,3423,2432,2412],
       'house_no':[12312,234,2344,123]}
df = pd.DataFrame(data9)
df
# Out:
#    emp_id  mobile_no  house_no
# 0     101      12321     12312
# 1     102       3423       234
# 2     104       2432      2344
# 3     103       2412       123

# %%
df1 = pd.DataFrame(data10)
df1
# Out:
#    emp_id  mobile_no  house_no
# 0     101      12321     12312
# 1     102       3423       234
# 2     104       2432      2344
# 3     103       2412       123

# %%
pd.merge(df,df1)
# Out:
#    emp_id  salary  providentfund  mobile_no  house_no
# 0     101      12          12312      12321     12312
# 1     102      45           3432       3423       234
# 2     103      53            234       2412       123
# 3     104      45            535       2432      2344

# %%
pd.concat([df,df1])
# Out:
#    emp_id  salary  providentfund  mobile_no  house_no
# 0     101    12.0        12312.0        NaN       NaN
# 1     102    45.0         3432.0        NaN       NaN
# 2     103    53.0          234.0        NaN       NaN
# 3     104    45.0          535.0        NaN       NaN
# 0     101     NaN            NaN    12321.0   12312.0
# 1     102     NaN            NaN     3423.0     234.0
# 2     104     NaN            NaN     2432.0    2344.0
# 3     103     NaN            NaN     2412.0     123.0

# %%
#4

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
k = sns.load_dataset('iris')

# %%
k
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.plot.scatter(x='sepal_length',y = 'sepal_width')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
df.plot.scatter(x='sepal_length',y = 'petal_length', c='sepal_length')#extra
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.hexbin(x='sepal_length',y='petal_length', gridsize=10,cmap="viridis")
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot(kind='hist', figsize=(10,10))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
#5

# %%
x = np.linspace(-1,6,30)
y=np.linspace(-1,6,30)
z = x+y
def sin_fun(x,y):
    return np.sin(np.sqrt(x**2+y**2))
z = sin_fun(x,y)
ax = plt.axes(projection = '3d')
ax.plot3D(x,y,z)

# %%
ax = plt.axes(projection = '3d')
ax.plot3D(df['sepal_length'],df['petal_length'],df['petal_width'])
ax.set_xlabel('sepal_length')
ax.set_ylabel('petal_length')
ax.set_zlabel("sepal_width")
# Out:
# Text(0.5, 0, 'sepal_width')

# %%
z = [3, 7, 4, 2]
k = [z(0)+0,z(1)+1,z(2)+2,z(3)+3]
print (k)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2256\384721704.py in <module>
#       1 z = [3, 7, 4, 2]
# ----> 2 k = [z(0)+0,z(1)+1,z(2)+2,z(3)+3]
#       3 print (k)
#
# TypeError: 'list' object is not callable

# %%
def add_indexes(arr, n, k):
    for i in range(0, k):
        x = arr[0]
        for j in range(0, n-1):
            arr[j] = arr[j] + arr[i]
arr = [12, 10, 5, 6, 52, 36]
n = len(arr)
position = 3
 
print (add_indexes(arr, n, position))
# Out:
# None

# %%
python_list = ['1','1','1'] # declare the list

for i in range(0, len(python_list)) : # iterate through each index i
    k = i + python_list[j]
print(k)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17432\3931479275.py in <module>
#       2
#       3 for i in range(0, len(python_list)) : # iterate through each index i
# ----> 4     k = i + python_list[j]
#       5 print(k)
#
# NameError: name 'j' is not defined
